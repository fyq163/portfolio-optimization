# %%
import pandas as pd
Data_Path = 'washed.csv'
df= pd.read_csv(Data_Path,parse_dates=True,index_col=0)
ExcessReturns=pd.DataFrame()
SP50 = df['SP50']
for col in df.columns[0:-1]:
    ExcessReturns.loc[:,col]=df[col]-SP50
ExcessReturns
# Out:
#                 C-US  GOOGL-US   INTC-US   NVDA-US   EBAY-US     HD-US  \
# Date
# 2014-01-31 -0.055047  0.088344 -0.019943  0.014599  0.004227 -0.032101
# 2014-02-28 -0.020443 -0.016378 -0.027127  0.130267  0.058955  0.021660
# 2014-03-31 -0.029586 -0.091604  0.034163 -0.033977 -0.068470 -0.038181
# 2014-04-30 -0.000879 -0.048472  0.026543  0.023875 -0.069123 -0.002590
# 2014-05-30 -0.030363  0.045270  0.008931  0.010015 -0.044697 -0.014419
# 2014-06-30 -0.030538  0.002119  0.110382 -0.044868 -0.033865 -0.005680
# 2014-07-31  0.052432  0.005034  0.110555 -0.042304  0.069125  0.012432
# 2014-08-29  0.016016 -0.035156 -0.002549  0.076301  0.010534  0.116458
# 2014-09-30  0.017315  0.024412  0.011160 -0.037390  0.034384  0.000259
# 2014-10-31  0.008768 -0.059333 -0.047688  0.034653 -0.097355  0.038579
# 2014-11-28 -0.018675 -0.059983  0.075671  0.050847  0.018439 -0.007617
# 2014-12-31  0.005113 -0.031028 -0.023253 -0.041353  0.025114  0.063612
# ...
